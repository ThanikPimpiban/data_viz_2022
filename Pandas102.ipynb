# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanikPimpiban/data_viz_2022/blob/main/Pandas102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/My Drive/dataviz_2021_data/dataviz_2021_data'

# %%
covid_file_path = os.path.join(path,'pm-20-jan-2021.csv') 
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/dataviz_2021_data/pm-20-jan-2021.csv

# %%
a = path + '/pm-18-jan-2021.csv' 
print(a)
# Out:
# /content/drive/My Drive/dataviz_2021_data/dataviz_2021_data/pm-18-jan-2021.csv

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %% [markdown]
# # ต่อตาราง
#
# * ต่อในแนวแกน X (เพิ่มจำนวนข้อมูล)
# * ต่อในแนวแกน Y (รายละเอียดของข้อมูล)

# %% [markdown]
# ตรวจสอบค่าใน column

# %%
import numpy as np

# %%
set(data_covid['province_of_onset'])
# Out:
# {nan,
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'คลองใหญ่',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชากบก',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บางบุตร',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พม่า',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มาบตาพุด',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สมุุทรสงคราม',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
# ...

# %%
BKK = data_covid[data_covid['province_of_onset']=='กรุงเทพมหานคร']
BKK
# Out:
#          No.  ...                                           risk
# 0          1  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# 5          6  ...               คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                            ...
# 12616  12617  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12617  12618  ...   ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 12618  12619  ...   ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 12619  12620  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12647  12648  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
#
# [2789 rows x 10 columns]

# %%
KKC = data_covid[data_covid['province_of_onset']=='ขอนแก่น']
KKC
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %% [markdown]
# ต่อคารางให้เป็นข้อมูล 2 จังหวัด

# %%
dataBKKKKC = pd.concat([BKK,KKC])
dataBKKKKC
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 5          6  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 9334    9335  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                         อยู่ระหว่างการสอบสวน
# 11697  11698  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11698  11699  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [2803 rows x 10 columns]

# %% [markdown]
# ต่อแกน x

# %%
personal_data = data_covid[['No.','sex','age','nationality']]
personal_data
# Out:
#          No.   sex   age nationality
# 0          1  หญิง  61.0       China
# 1          2  หญิง  74.0       China
# 2          3  หญิง  73.0    Thailand
# 3          4   ชาย  68.0       China
# 4          5  หญิง  66.0       China
# ...      ...   ...   ...         ...
# 12648  12649  หญิง  44.0    Thailand
# 12649  12650  หญิง  52.0    Thailand
# 12650  12651  หญิง  23.0    Thailand
# 12651  12652  หญิง  29.0    Thailand
# 12652  12653  หญิง  22.0       Burma
#
# [12653 rows x 4 columns]

# %%
covid = data_covid[['No.','announce_date','province_of_isolation','province_of_onset','risk']].sample(frac=1)
covid
# Out:
#        No.  ...                                               risk
# 2402  2403  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 9295  9296  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 7425  7426  ...       ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 1263  1264  ...                                        สถานบันเทิง
# 2788  2789  ...                                        สถานบันเทิง
# ...    ...  ...                                                ...
# 2348  2349  ...                                   State Quarantine
# 4653  4654  ...                                  Cluster สมุทรสาคร
# 9516  9517  ...                               อยู่ระหว่างการสอบสวน
# 2736  2737  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1266  1267  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 5 columns]

# %% [markdown]
# เอาตารางมาต่อกัน

# %%
personalcovid = personal_data.merge(covid)
personalcovid
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 8 columns]

# %%
covidpersonal = covid.merge(personal_data)
covidpersonal
# Out:
#         No. announce_date province_of_isolation  ...   sex   age nationality
# 0      2403      4/9/2020              ปทุมธานี  ...  หญิง  37.0    Thailand
# 1      9296      1/6/2021                ชลบุรี  ...   ชาย  42.0    Thailand
# 2      7426      1/3/2021         กรุงเทพมหานคร  ...  หญิง  30.0       India
# 3      1264     3/29/2020         กรุงเทพมหานคร  ...   ชาย  48.0    Thailand
# 4      2789     4/20/2020         กรุงเทพมหานคร  ...  หญิง  20.0    Thailand
# ...     ...           ...                   ...  ...   ...   ...         ...
# 12648  2349      4/8/2020                  สตูล  ...   ชาย  43.0    Thailand
# 12649  4654    12/20/2020             สมุทรสาคร  ...   NaN   NaN       Burma
# 12650  9517      1/7/2021                 ระยอง  ...   ชาย  62.0    Thailand
# 12651  2737     4/19/2020         กรุงเทพมหานคร  ...   ชาย  37.0    Thailand
# 12652  1267     3/29/2020         กรุงเทพมหานคร  ...   ชาย  44.0       Spain
#
# [12653 rows x 8 columns]

# %% [markdown]
# save table

# %%
personalcovid.to_csv(os.path.join(path,'my_personal_data.csv'))  ## save ลง GG Drive

# %%
personalcovid.to_csv('my_personal_data.csv')  ## save ลง colab

# %% [markdown]
# group by

# %%
data_covid.groupby('nationality').count()
# Out:
#                 No.  announce_date  ...  district_of_onset  risk
# nationality                         ...
# Afghanistan       1              1  ...                  1     1
# Albania           3              3  ...                  2     3
# American          1              1  ...                  1     1
# American          1              1  ...                  1     1
# American Samoa    1              1  ...                  1     1
# ...             ...            ...  ...                ...   ...
# deutsch           1              1  ...                  1     1
# thailand          2              2  ...                  2     2
# ต่างด้าว         21             21  ...                 21    21
# ไทยใหญ่           1              1  ...                  1     1
# ไทใหญ่            1              1  ...                  1     1
#
# [100 rows x 9 columns]

# %%
data_covid.groupby('nationality')['age'].min(' ')   ## ศึกษา min(' ')
# Out:
# nationality
# Afghanistan       31.0
# Albania           33.0
# American          39.0
# American          46.0
# American Samoa    21.0
#                   ...
# deutsch           55.0
# thailand          50.0
# ต่างด้าว          13.0
# ไทยใหญ่           30.0
# ไทใหญ่            33.0
# Name: age, Length: 100, dtype: float64
