# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanikPimpiban/data_viz_2022/blob/main/FinalExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1= pd.read_csv('/content/drive/MyDrive/ovrdt data/alldb.csv')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data1 ## แสดงข้อมูล
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# ...

# %%
data2= pd.read_excel('/content/drive/MyDrive/ovrdt data/hospital_list.xlsx')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data2 ## แสดงข้อมูล
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40035 entries, 0 to 40034
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    40035 non-null  int64
#  1   user          39273 non-null  object
#  2   RowKey        40034 non-null  object
#  3   care          72 non-null     object
#  4   date          39481 non-null  object
#  5   ov            39671 non-null  object
#  6   phone         40032 non-null  object
#  7   site          39936 non-null  object
#  8   time          39478 non-null  object
#  9   urine         39782 non-null  object
#  10  pid           145 non-null    object
#  11  PartitionKey  39850 non-null  object
#  12  title         39591 non-null  object
#  13  age           39493 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 4.3+ MB

# %%
data1['date'] = pd.to_datetime(data1['date'],format='%Y/%m/%d')

# %%
data1['time'] = pd.to_datetime(data1['time'],format='%HH/%mm/%SS')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-a177c0514b22> in <module>()
# ----> 1 data1['time'] = pd.to_datetime(data1['time'],format='%HH/%mm/%SS')
#
# ...

# %%
data1['phone']=data1['phone'].astype('string')

# %%
data1['urine']=data1['urine'].astype('string')

# %%
TF1=list() ## กำหนด TF ให้เป็น list ว่าง เพื่อใช้เติมค่า loop
for each_row in data1.iterrows(): ## loop each_row ใน data1
    if len(str(each_row[1]['user']))== 5 : #สร้างเงื่อนไข user ที่มีจำนวนตัวอักษรเท่ากับ 5
        if str(each_row[1]['user']) <= '99999' :
            TF1.append(True) ## หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน TF
        elif str(each_row[1]['user']) >= '99999' :
            TF1.append(False)
    else:
        TF1.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF

data1[TF1] ## แสดงผล
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
# 40017       40017  12345                        zgvicawbkg.png  NaN
#
#             date   ov             phone   site      time  \
# 1     2022-02-24  NaN        iPhone10,4  05310  10:50:32
# ...

# %%
df1 =data1[TF1]

# %%
df1_clean = df1[df1['user']!= '6724-']

# %%
df1_clean['user'].astype('int64')
# Out:
# 1         4857
# 5         8777
# 7         4857
# 11        8777
# 12       11111
#          ...
# 39813    99999
# 39814    99999
# 39815    99999
# 39816    99999
# 40017    12345
# Name: user, Length: 38509, dtype: int64

# %%
set(df1['user'])
# Out:
# {'76475',
#  '73557',
#  '50577',
#  '17184',
#  '56326',
#  '00404',
#  '71152',
#  '76088',
#  '40865',
#  '00297',
#  '14667',
#  '33171',
#  '10724',
#  '05182',
#  '19250',
#  '28627',
#  '68081',
#  '63485',
#  '86545',
#  '73225',
#  '85934',
#  '14106',
#  '00203',
#  '16904',
#  '00322',
#  '00020',
#  '00138',
#  '01009',
#  '00341',
#  '16604',
#  '58271',
#  '73204',
#  '52481',
#  '03263',
#  '13088',
#  '05135',
#  '00125',
#  '71872',
#  '10348',
#  '84495',
#  '20435',
#  '00141',
#  '00118',
#  '27658',
#  '45787',
#  '09259',
#  '46341',
#  '10105',
#  '66801',
#  '00030',
#  '00266',
#  '31755',
#  '14255',
#  '66261',
#  '86133',
#  '54100',
#  '91167',
#  '64211',
#  '00251',
#  '44845',
#  '00053',
#  '00578',
#  '25829',
#  '16193',
#  '00113',
#  '53045',
#  '34322',
#  '30311',
#  '55873',
#  '01850',
#  '40886',
#  '00124',
#  '96349',
#  '99884',
#  '96292',
#  '92747',
#  '92648',
#  '87802',
#  '84375',
#  '79620',
#  '48710',
#  '38500',
#  '36481',
# ...

# %%
data_clean = data1[TF1][data1[TF1]['user']!='ttest']

# %%
data_clean2 = data_clean[data_clean['user']!='ttohn']

# %%
TF2=list() ## กำหนด TF ให้เป็น list ว่าง เพื่อใช้เติมค่า loop
for each_row in data_clean2.iterrows(): ## loop each_row ใน data1
    if len(str(each_row[1]['site']))== 5 : #สร้างเงื่อนไข user ที่มีจำนวนตัวอักษรเท่ากับ 5
        TF2.append(True) ## หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน TF
    else:
        TF2.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF

data_clean2[TF2] ## แสดงผล
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
# 40017       40017  12345                        zgvicawbkg.png  NaN
#
#             date   ov             phone   site      time  \
# 1     2022-02-24  NaN        iPhone10,4  05310  10:50:32
# ...

# %%
data_clean3 =data_clean2[TF2]

# %%
TF3=list() ## กำหนด TF ให้เป็น list ว่าง เพื่อใช้เติมค่า loop
for each_row in df1.iterrows(): ## loop each_row ใน data1
    if len(str(each_row[1]['user']))== 5 : #สร้างเงื่อนไข user ที่มีจำนวนตัวอักษรเท่ากับ 5
        if int(each_row[1]['user']) <= 99999 :
            TF3.append(True) ## หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน TF
        else:
            TF3.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF

df1[TF3] ## แสดงผล
# Out:
#   File "<ipython-input-122-badee8389e7b>", line 5
#     elif int(each_row[1]['user']) <= 99999 :
#        ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-7fcfc2182c5c> in <module>()
# ----> 1 data_clean3['user'].astype('int64')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %% [markdown]
# # Data processing
